# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
from sklearn.preprocessing import minmax_scale

# %%
data = pd.read_csv('./data/glass.csv', delimiter=',')
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
var_names = list(data.columns)
labels = data.to_numpy('int')[:, -1]
features = data.to_numpy('float')[:, : -1]

# %%
# Data normalization
normalize(features, norm="l2")
# Out:
# array([[0.02062461, 0.18495587, 0.06088357, ..., 0.11864837, 0.        ,
#         0.        ],
#        [0.02035047, 0.18625869, 0.04827439, ..., 0.1049968 , 0.        ,
#         0.        ],
#        [0.02028154, 0.18098728, 0.04748742, ..., 0.10407103, 0.        ,
#         0.        ],
#        ...,
#        [0.02018222, 0.19058739, 0.        , ..., 0.11201654, 0.02176625,
#         0.        ],
#        [0.02007671, 0.19037334, 0.        , ..., 0.11226467, 0.02078485,
#         0.        ],
#        [0.02015143, 0.18901387, 0.        , ..., 0.11449751, 0.02218223,
#         0.        ]])

# %%
minmax_scale(features, axis=1)
# Out:
# array([[0.02118989, 0.19002508, 0.06255224, ..., 0.12190025, 0.        ,
#         0.        ],
#        [0.02086636, 0.19098034, 0.04949814, ..., 0.10765846, 0.        ,
#         0.        ],
#        [0.02077243, 0.18536786, 0.0486368 , ..., 0.10658994, 0.        ,
#         0.        ],
#        ...,
#        [0.02071166, 0.19558703, 0.        , ..., 0.11495505, 0.02233724,
#         0.        ],
#        [0.02060196, 0.19535389, 0.        , ..., 0.11520174, 0.02132862,
#         0.        ],
#        [0.02068034, 0.19397492, 0.        , ..., 0.11750273, 0.02276445,
#         0.        ]])

# %%
fig, axs = plt.subplots(2, 4)
for i in range(features.shape[1]-1):
    axs[i // 4, i % 4].scatter(features[:, i], features[:, (i + 1)], c=labels, cmap='hsv')
    axs[i // 4, i % 4].set_xlabel(var_names[i])
    axs[i // 4, i % 4].set_ylabel(var_names[i + 1])
plt.show()
